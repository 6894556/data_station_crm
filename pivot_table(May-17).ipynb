# %%
import pandas as pd

# %%
df1 = pd.read_csv("01_Contract_Data.csv")

# %% [markdown]
# -

# %% [markdown]
# pivot_table 사용법
# - excel에도 pivot이라는 기능이 있다.
# > 항목 1에 따라서, 특정 값을 계산해주는 기능
# - 성별에 따라서 매출액 차이가 있는가?
# - 결제은행에 따라서 연체건수에 차이가 있는가?
# 구분할 수 있는 범주형 항목에 따라서 숫자 데이터의 통계량을 계산하는 함수

# %% [markdown]
# pivot_table 쓰기 전에 groupby, pivot 함수를 쓴다.
# - 실무에서는 pivot_table 사용하면 대부분의 데이터를 항목별로 계산 or 정리를 해줄 수 있다.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51301 entries, 0 to 51300
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          51301 non-null  int64
#  1   Member_ID      51301 non-null  int64
#  2   Sales_Type     51301 non-null  object
#  3   Contract_Type  51301 non-null  object
#  4   Channel        51301 non-null  object
#  5   Datetime       51301 non-null  object
#  6   Term           51301 non-null  int64
#  7   Payment_Type   51301 non-null  object
#  8   Product_Type   51301 non-null  object
#  9   Amount_Month   51301 non-null  int64
#  10  Customer_Type  51299 non-null  object
#  11  Age            44329 non-null  float64
#  12  Address1       51299 non-null  object
#  13  Address2       51299 non-null  object
#  14  State          51301 non-null  object
#  15  Overdue_count  51301 non-null  int64
#  16  Overdue_Type   51301 non-null  object
# ...

# %%
# 유입 채널에 따라서 월 렌탈 비용에 차이가 있는가?
# 채널별 월 결제액의 평균
# crm 같은 데이터는 mean 보다는 sum을 더 많이 계산한다.
df1.pivot_table(index="Channel", values="Amount_Month", aggfunc="mean")
# Out:
#           Amount_Month
# Channel
# 대형마트A     97016.330159
# 대형마트C     95276.974790
# 대형마트E    100423.647295
# 대형마트H    100025.333333
# 대형마트N     76514.457831
# 영업방판     100322.794631
# 자체홈페이지    98402.500000
# 재계약       67176.744186
# 전단홍보     104048.571429
# 전문매장H     72514.008677
# 전문매장Z     98127.363184
# 직영계열사A   104970.000000
# 직영계열사B   111300.000000
# 직영유통사    119011.117021
# 홈쇼핑/방송    89092.232411
# 홈쇼핑/인터넷   96685.600000

# %%
# aggfunc: 특정 통계량을 계산하는 기능
df1.pivot_table(index="Channel", values="Amount_Month", aggfunc="sum")
# Out:
#          Amount_Month
# Channel
# 대형마트A       458402160
# 대형마트C        11337960
# 대형마트E       150334200
# 대형마트H        22505700
# 대형마트N         6350700
# 영업방판       2384371860
# 자체홈페이지       11808300
# 재계약         147318600
# 전단홍보         58267200
# 전문매장H       234002706
# 전문매장Z       118341600
# 직영계열사A        2099400
# 직영계열사B        2114700
# 직영유통사        22374090
# 홈쇼핑/방송     1156149900
# 홈쇼핑/인터넷      36257100

# %%
# pivot table 사용하면 다양한 분석이 가능해진다.
# 구분하고 싶은 항목이 두 개 이상의 범주 항목인 경우
# e.g. 채널과 성별에 따라서 월 결제액
df1.pivot_table(index=["Channel", "Gender"], values="Amount_Month", aggfunc="mean")
# Out:
#                  Amount_Month
# Channel Gender
# 대형마트A   남자       96521.515368
#         여자       97224.461816
# 대형마트C   여자       95276.974790
# 대형마트E   남자      100724.414062
#         여자      100267.309645
# 대형마트H   남자      100611.111111
#         여자       99695.833333
# 대형마트N   남자       76119.512195
#         여자       76900.000000
# 영업방판    남자      100059.535067
#         여자      100446.886646
# 자체홈페이지  남자      100281.250000
#         여자       97150.000000
# 재계약     남자       67257.421875
#         여자       67133.263158
# 전단홍보    남자      105357.485030
#         여자      103492.366412
# 전문매장H   남자       99922.424242
#         여자       67547.989019
# 전문매장Z   남자       97738.163265
#         여자       98393.715084
# 직영계열사A  여자      104970.000000
# 직영계열사B  여자      111300.000000
# 직영유통사   여자      119011.117021
# 홈쇼핑/방송  남자       88578.558875
#         여자       89319.713142
# 홈쇼핑/인터넷 남자       96781.188119
#         여자       96650.364964

# %% [markdown]
# - index와 values, aggfunc에 list 형태 구조를 집어 넣을 수 있다.

# %%
# 성별에 따른 채널별 월 렌탈비용의 합 
df1.pivot_table(index=["Gender", "Channel"], values="Amount_Month", aggfunc="sum")
# Out:
#                 Amount_Month
# Gender Channel
# 남자     대형마트A       135033600
#        대형마트E        51570900
#        대형마트H         8149500
#        대형마트N         3120900
#        영업방판        761853300
#        자체홈페이지        4813500
#        재계약          51653700
#        전단홍보         17594700
#        전문매장H        49461600
#        전문매장Z        47891700
#        홈쇼핑/방송      352808400
#        홈쇼핑/인터넷       9774900
# 여자     대형마트A       323368560
#        대형마트C        11337960
#        대형마트E        98763300
#        대형마트H        14356200
#        대형마트N         3229800
#        영업방판       1622518560
#        자체홈페이지        6994800
#        재계약          95664900
#        전단홍보         40672500
#        전문매장H       184541106
#        전문매장Z        70449900
#        직영계열사A        2099400
#        직영계열사B        2114700
#        직영유통사        22374090
#        홈쇼핑/방송      803341500
#        홈쇼핑/인터넷      26482200

# %%
# overdue count : 연체건수
# 동시에 2개의 범주형 항목으로 데이터를 나누어 2개의 숫자형 항목 데이터에 대한 통계량 계산
df1.pivot_table(index=["Gender", "Channel"], values=["Amount_Month", "Overdue_count"])
# Out:
#                  Amount_Month  Overdue_count
# Gender Channel
# 남자     대형마트A     96521.515368       0.250893
#        대형마트E    100724.414062       0.173828
#        대형마트H    100611.111111       0.259259
#        대형마트N     76119.512195       0.000000
#        영업방판     100059.535067       0.273575
#        자체홈페이지   100281.250000       0.020833
#        재계약       67257.421875       0.217448
#        전단홍보     105357.485030       0.125749
#        전문매장H     99922.424242       0.258586
#        전문매장Z     97738.163265       0.087755
#        홈쇼핑/방송    88578.558875       0.119508
#        홈쇼핑/인터넷   96781.188119       0.198020
# 여자     대형마트A     97224.461816       0.166266
#        대형마트C     95276.974790       0.000000
#        대형마트E    100267.309645       0.104569
#        대형마트H     99695.833333       0.152778
#        대형마트N     76900.000000       0.000000
#        영업방판     100446.886646       0.173590
#        자체홈페이지    97150.000000       0.041667
# ...

# %%
# 성별과
# 채널에 따른
# Amount_Month와 Overdue_count의 합, 최소값, 최대값을 한번에 계산 
df1.pivot_table(index=["Gender", "Channel"], values=["Amount_Month", "Overdue_count"], aggfunc=["sum", "min", "max"])
# Out:
#                         sum                        min                \
#                Amount_Month Overdue_count Amount_Month Overdue_count
# Gender Channel
# 남자     대형마트A      135033600           351        55200             0
#        대형마트E       51570900            89        81900             0
#        대형마트H        8149500            21        87900             0
#        대형마트N        3120900             0        75900             0
#        영업방판       761853300          2083        78900             0
#        자체홈페이지       4813500             1        84900             0
#        재계약         51653700           167        55200             0
#        전단홍보        17594700            21        87900             0
#        전문매장H       49461600           128        81900             0
#        전문매장Z       47891700            43        81900             0
#        홈쇼핑/방송     352808400           476        80400             0
# ...

# %% [markdown]
# - columns:

# %%
# Datetime: 영업일자, 계약일자
# 일자별로 Sales_Type에 따른 Amount_Month의 합 (매출액)
# sales type에 따라서 data가 찍힌다: 577일 -> 너무 많다.
df1.pivot_table(index="Sales_Type", values="Amount_Month", columns="Datetime", aggfunc="sum")
# Out:
# Datetime    2019-01-01  2019-01-02  2019-01-03  2019-01-04  2019-01-05  \
# Sales_Type
# 렌탈           4346700.0   4957800.0   7011300.0   5276700.0   5170950.0
# 멤버십           209700.0     66900.0    255900.0    133800.0    334500.0
#
# Datetime    2019-01-06  2019-01-07  2019-01-08  2019-01-09  2019-01-10  ...  \
# Sales_Type                                                              ...
# 렌탈           4445700.0   8282400.0   5970150.0   5577600.0   6996900.0  ...
# 멤버십           142800.0    255900.0         NaN    133800.0    133800.0  ...
#
# Datetime    2020-07-29  2020-07-30  2020-07-31  2020-08-01  2020-08-02  \
# Sales_Type
# 렌탈           5478600.0   7551300.0  10361100.0   6187500.0   2779200.0
# 멤버십           302361.0    383322.0    730365.0    671079.0    188403.0
#
# Datetime    2020-08-03  2020-08-04  2020-08-05  2020-08-06  2020-08-07
# Sales_Type
# 렌탈           2953500.0   2732700.0   3034260.0   2523000.0   2111100.0
# ...

# %%
# 577 columns가 너무 많다. 
# 그러니 Datetime을 datetime 처리해서 
# 주차별, 월별, 연도별 지출액을 계산해보자
df1["Datetime(dt)"] = pd.to_datetime(df1["Datetime"], format="%Y-%m-%d")

# %%
# Year, Month 열 만들고 연도별, 월별 지출액 계산
df1["Year"] = df1["Datetime(dt)"].dt.year
df1["Month"] = df1["Datetime(dt)"].dt.month

# %%
# 월별로 판매 채널에 따른 월 요금의 평균: 
df1.pivot_table(index="Sales_Type", columns="Month", values="Amount_Month")
# Out:
# Month                 1             2             3             4   \
# Sales_Type
# 렌탈          96492.490173  97556.468305  97173.104859  97248.904656
# 멤버십         65276.747664  62586.006897  63107.606965  62506.710526
#
# Month                 5             6             7             8   \
# Sales_Type
# 렌탈          97181.640167  97065.566213  97238.461711  97473.638271
# 멤버십         63166.083770  63153.805479  63251.280943  63221.884615
#
# Month                 9             10            11            12
# Sales_Type
# 렌탈          97348.261894  96986.906574  97392.284672  97608.871939
# 멤버십         62816.128631  62210.300353  62704.071429  62721.843416

# %%
# 월별 매출의 추이: 19년도 1월 데이터와 20년도 1월 데이터가 합쳐져서 계산이 된 것이다.
df1.pivot_table(index="Sales_Type", columns="Month", values="Amount_Month", aggfunc="sum")
# Out:
# Month              1          2          3          4          5          6   \
# Sales_Type
# 렌탈          564577560  754111500  569920260  438592560  348396180  313715910
# 멤버십          27938448   54449826   38053887   28503060   24129444   23051139
#
# Month              7          8          9          10         11         12
# Sales_Type
# 렌탈          433002870  232279680  206670360  280292160  133427430  243143700
# 멤버십          32194902   16437690   15138687   17605515    8778570   17624838

# %%
# 19년, 20년을 나눠서 월별 매출 합 계산
df1.pivot_table(index="Sales_Type", columns=["Year", "Month"], values="Amount_Month", aggfunc="sum")
# Out:
# Year             2019                                                         \
# Month              1          2          3          4          5          6
# Sales_Type
# 렌탈          394690080  581147940  423192960  318915930  263786940  236969310
# 멤버십          17205900   44238291   27736254   20259312   19053555   17510016
#
# Year                                                                          \
# Month              7          8          9          10         11         12
# Sales_Type
# 렌탈          313217310  209958420  206670360  280292160  133427430  243143700
# 멤버십          24422919   14708643   15138687   17605515    8778570   17624838
#
# Year             2020                                                       \
# Month              1          2          3          4         5         6
# Sales_Type
# 렌탈          169887480  172963560  146727300  119676630  84609240  76746600
# 멤버십          10732548   10211535   10317633    8243748   5075889   5541123
#
# Year
# ...

# %%
# 이렇게 정리된 것을 excel 파일로 보고를 하고 싶다:
#df1.pivot_table(index="Sales_Type", columns=["Year", "Month"], values="Amount_Month", aggfunc="sum").to_excel("result1.xlsx")

# %%
# erp라는 데이터가 모여있는 공간에서 데이터를 가져와서
# 이런 식으로 보고서를 써야하는 경우가 많이 있다. weekly report, monthly report
# python 코드로 pivot table로 logic을 만들어 놓으면 
# 매주 똑같은 작업을 반복해서 할 필요 없이
# 데이터 가져와서 실행만 시키면 
# 알아서 데이터가 처리 되고 파일로 저장까지 된다. -> 자동화

# %%
# 결제 은행별 월별 결제 금액의 합이 어떻게 되는가?
df1.pivot_table(index="Bank", columns="Month", values="Amount_Month", aggfunc="sum")
# Out:
# Month               1            2            3           4           5   \
# Bank
# BC카드        13861050.0   17040600.0   18356100.0  13517400.0   8998500.0
# NH농협카드        105900.0          NaN          NaN         NaN    126900.0
# SC제일은행       5866650.0    6409050.0    5074800.0   4279650.0   3644250.0
# SK증권               NaN          NaN          NaN         NaN         NaN
# 경남은행         5560200.0    6782100.0    6406800.0   4664100.0   3291000.0
# 광주은행         4374600.0    6754500.0    4083900.0   3750000.0   1994400.0
# 국민은행        70656600.0   91146900.0   74246100.0  55984200.0  43775679.0
# 국민카드        16005300.0   19740600.0   17868900.0  12062700.0   8166300.0
# 기업은행        26801100.0   33640350.0   21714450.0  16829250.0  14071800.0
# 농협중앙회       44864700.0   61123800.0   48209700.0  37406400.0  29891100.0
# 농협회원조합      74546979.0  100832100.0   73452000.0  57693600.0  50416800.0
# 대구은행         8161500.0   12276000.0    7927500.0   8072400.0   5581200.0
# ...

# %% [markdown]
# - margins=True : 총합 계산
# > All이 index 마지막에 붙는다. 모든 은행 총합 값
#
# 강력한 기능

# %%
# 결제 은행별 월별 결제 금액의 합의 총합
df1.pivot_table(index="Bank", values="Amount_Month", aggfunc="sum", margins=True)
# Out:
#            Amount_Month
# Bank
# BC카드          120408150
# NH농협카드           545400
# SC제일은행         42455400
# SK증권              90900
# 경남은행           42701700
# 광주은행           32907000
# 국민은행          572284179
# 국민카드          125086200
# 기업은행          190178979
# 농협중앙회         371847000
# 농협회원조합        601133079
# 대구은행           71830800
# 대신증권             105900
# 대우증권             163800
# 롯데카드          896422200
# 메리츠종합금융증권         87900
# 미래에셋증권           499500
# 부산은행           84919500
# 산림조합중앙회           96900
# 산업은행            2388900
# 삼성증권             603300
# 삼성카드           83970000
# 상호저축은행            96900
# 새마을금고          92481900
# 수협중앙회          15868800
# 수협카드             105900
# 신한금융투자           375600
# 신한은행          337695600
# 신한카드          146170500
# 신협중앙회          32284500
# 씨티은행           15556500
# 씨티카드             124200
# 외환은행           56088900
# 외환카드           50771400
# 우리은행          324049500
# 우리카드             272700
# 우체국            68319300
# ...

# %%
# Product_Type별 Amount_Month의 sum과 매출액의 총액 : 제품별합, 전체합
df1.pivot_table(index="Product_Type", values="Amount_Month", aggfunc="sum", margins=True)
# Out:
#               Amount_Month
# Product_Type
# DES-1           3695115726
# DES-2            787657290
# DES-3A           197085060
# DES-R4            42328500
# ERA               77115600
# MMC               22734000
# All             4822036176

# %%
# 제품별합, 전체합을 연도별로 보겠다면: columns="Year" 
# + 연도별 총합도 계산된다.
# 이렇게 하면 전년 대비 매출액의 변화 추이도 살펴볼 수 있다.
# 실무에서도 이런 항목을 많이 본다: 전년 대비 매출 증감률, 고객 증감율

df1.pivot_table(index="Product_Type", values="Amount_Month", aggfunc="sum", columns="Year").to_excel("result2.xlsx")

# %%
# pivot_table을 잘 사용하면, 
# 굉장히 다양하고 많은 데이터에서, 
# 데이터를 항목별로 나눠서
# 특정 값에 대한 통계량을 확인하면서 굉장히 많은 인사이트를 얻어낼 수 있다.

# %%
# Product Type따른 연도별 매출액
df3 = df1.pivot_table(index="Product_Type", columns="Year", values="Amount_Month", aggfunc="sum")

# %%
# Product Type따른 연도별 매출액의 차이: 음의 값이므로 줄었다.
df3["증감액"] = df3[2020] - df3[2019]

# %%
# 증감액: 음의 값이다. 
# 월을 계산하지 않았기 때문에 음의 값이 나온 것이다.
# 19년도는 1-12월 데이터가 있지만 20년도는 1월부터 8월까지 데이터만 있으므로
# 즉 20년도에 4개월이 비기 떄문에 증감액에 차이가 있다. -> 이것도 이따가 처리해보자.
df3
# Out:
# Year                2019       2020         증감액
# Product_Type
# DES-1         2946278610  748837116 -2197441494
# DES-2          631877970  155779320  -476098650
# DES-3A         157162560   39922500  -117240060
# DES-R4          33891300    8437200   -25454100
# ERA             62944500   14171100   -48773400
# MMC             17540100    5193900   -12346200

# %%
# 9년도는 1-12월 데이터가 있지만 20년도는 몇월부터 몇월까지 있는지 확인하는 방법?

# %%
# 증감액을 갖고 증감률(얼마나 증감했는가에 대한 비율)을 계산
df3["증감률"] = df3["증감액"] / (df3[2020] + df3[2019])

# %%
# 증감액과 증감률이 음의 값이 나올 수 밖에 없다.
# 19년도 1-12월, 20년도 1-8월이므로.
# 따라서 19년도 1-8월, 20년도 1-8월을 갖고 증감액과 증감률을 계산해야 한다.
df3
# Out:
# Year                2019       2020         증감액       증감률
# Product_Type
# DES-1         2946278610  748837116 -2197441494 -0.594688
# DES-2          631877970  155779320  -476098650 -0.604449
# DES-3A         157162560   39922500  -117240060 -0.594870
# DES-R4          33891300    8437200   -25454100 -0.601347
# ERA             62944500   14171100   -48773400 -0.632471
# MMC             17540100    5193900   -12346200 -0.543072

# %%
# 20년도에 정확히 몇월부터 몇월까지 있는지 확인해보기
#cond1 = (df1["Year"] == 2020)
#df1.loc[cond1]["Month"].unique()
# 20년도는 정확히 1-8월 데이터만 있음

# 19년도에 정확히 몇월부터 몇월까지 있는지 확인해보기
#cond1 = (df1["Year"] == 2019)
#df1.loc[cond1]["Month"].unique()
# 19년도는 정확히 1-12월 데이터만 있음

# %%
# 19년도 1-8월 데이터와
# 20년도 전체 데이터만 추출(filtering)하기
cond1 = df1["Year"] == 2019
cond2 = (df1["Month"] <= 8)
cond3 = (df1["Year"] == 2020)

# 이 df를 갖고 증감액과 증감률을 계산해야 한다.
# 그래야 정확한 전년 대비, 금년 매출액의 추이를 계산할 수 있다.
df4 = df1.loc[(cond1 & cond2) | cond3]

# %%
# 추이를 계산할 때는 sum을 사용한다.
# 매출액을 다시 계산했다.
# 19년도 1-8월, 20년도 전체(1-8월) product type에 따른 연도별 매출액의 추이
df5 = df4.pivot_table(index="Product_Type", values="Amount_Month", columns="Year", aggfunc="sum")

# %%
# 실제로 적자이다. 매출액이 개선되지 않고 있다.
df5["증감액"] = df5[2020] - df5[2019]
df5["증감률"] = df5["증감액"] / (df5[2019] + df5[2020])

# %%
# 19년 대비 매출이 약 50% 정도 대폭 감소했다.
# 증감률이 0보다 작다는 것은 매출액이 줄었다는 것을 뜻한다.
df5
# Out:
# Year                2019       2020         증감액       증감률
# Product_Type
# DES-1         2236446810  748837116 -1487609694 -0.498314
# DES-2          486777810  155779320  -330998490 -0.515127
# DES-3A         117017160   39922500   -77094660 -0.491238
# DES-R4          25721700    8437200   -17284500 -0.506003
# ERA             46972800   14171100   -32801700 -0.536467
# MMC             14077500    5193900    -8883600 -0.460973

# %%
# 이런 식으로 데이터를 분석해서
# 매출액의 추이를 분석할 수 있다.

# %%
# 이번 시간에는 
# pivot table을 이용해서
# 데이터를 요약하고 정리를 했다.

# 다음 시간에는
# melt를 이용해서
# 이렇게 정리되어 있는 데이터를
# 거꾸로 풀어보는 연습을 해볼거다. 

# 실무에서 데이터를 뽑으면 정리된 형태로 뽑히는 경우가 있다.
# 그럴 때, 데이터를 풀어헤쳐야 한다.
# 풀어헤치는 melt를 공부해보자.

# %% [markdown]
# - Mission
# > '01_Contract_Data.csv' 데이터의 'Datetime'항목을 처리하여, 요일 데이터를 추출한 뒤, 요일과 제품에 따른 'Amount_Month'의 합을 계산 해 보세요!

# %%
df1 = pd.read_csv("01_Contract_Data.csv")

# %%
df1["요일"] = pd.to_datetime(df1["Datetime"], format="%Y-%m-%d").dt.day_name()

# %%
df1.pivot_table(index=["요일", "Product_Type"], values="Amount_Month", aggfunc="sum")
# Out:
#                         Amount_Month
# 요일        Product_Type
# Friday    DES-1            542749254
#           DES-2            116072160
#           DES-3A            28468500
#           DES-R4             7143600
#           ERA               13280400
#           MMC                3402600
# Monday    DES-1            540517839
#           DES-2            112428060
#           DES-3A            28965600
#           DES-R4             4967400
#           ERA                9247800
#           MMC                2659800
# Saturday  DES-1            406091973
#           DES-2             87389670
#           DES-3A            21167550
#           DES-R4             4903800
#           ERA                9570000
#           MMC                3216900
# Sunday    DES-1            388083615
#           DES-2             79818960
#           DES-3A            20073150
#           DES-R4             4060800
#           ERA                8028300
#           MMC                1917000
# ...

# %%
df1.pivot_table(index="Product_Type", columns="요일", values="Amount_Month", aggfunc="sum")
# Out:
# 요일               Friday     Monday   Saturday     Sunday   Thursday  \
# Product_Type
# DES-1         542749254  540517839  406091973  388083615  615978612
# DES-2         116072160  112428060   87389670   79818960  136978050
# DES-3A         28468500   28965600   21167550   20073150   34292460
# DES-R4          7143600    4967400    4903800    4060800    7416900
# ERA            13280400    9247800    9570000    8028300   10898400
# MMC             3402600    2659800    3216900    1917000    4762500
#
# 요일              Tuesday  Wednesday
# Product_Type
# DES-1         607328556  594365877
# DES-2         130079850  124890540
# DES-3A         30982350   33135450
# DES-R4          6651300    7184700
# ERA            14400000   11690700
# MMC             3156900    3618300

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51301 entries, 0 to 51300
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          51301 non-null  int64
#  1   Member_ID      51301 non-null  int64
#  2   Sales_Type     51301 non-null  object
#  3   Contract_Type  51301 non-null  object
#  4   Channel        51301 non-null  object
#  5   Datetime       51301 non-null  object
#  6   Term           51301 non-null  int64
#  7   Payment_Type   51301 non-null  object
#  8   Product_Type   51301 non-null  object
#  9   Amount_Month   51301 non-null  int64
#  10  Customer_Type  51299 non-null  object
#  11  Age            44329 non-null  float64
#  12  Address1       51299 non-null  object
#  13  Address2       51299 non-null  object
#  14  State          51301 non-null  object
#  15  Overdue_count  51301 non-null  int64
#  16  Overdue_Type   51301 non-null  object
# ...
