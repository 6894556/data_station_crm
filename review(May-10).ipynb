# %%
import pandas as pd

# %%
df1 = pd.read_csv("01_Contract_Data.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51301 entries, 0 to 51300
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          51301 non-null  int64
#  1   Member_ID      51301 non-null  int64
#  2   Sales_Type     51301 non-null  object
#  3   Contract_Type  51301 non-null  object
#  4   Channel        51301 non-null  object
#  5   Datetime       51301 non-null  object
#  6   Term           51301 non-null  int64
#  7   Payment_Type   51301 non-null  object
#  8   Product_Type   51301 non-null  object
#  9   Amount_Month   51301 non-null  int64
#  10  Customer_Type  51299 non-null  object
#  11  Age            44329 non-null  float64
#  12  Address1       51299 non-null  object
#  13  Address2       51299 non-null  object
#  14  State          51301 non-null  object
#  15  Overdue_count  51301 non-null  int64
#  16  Overdue_Type   51301 non-null  object
# ...

# %% [markdown]
# ### Sorting
# 1. Amount_Month 기준으로 ascending sort
# 2. Amount_Month 기준으로 descending sort
# 3. Amount_Month, Age 기준으로 descending sort
# > 215700원 납부한 고객 중에, 나이가 높은 순서대로 정렬하기 위함
# 4. Amount_Month 기준으로 descending, Age 기준으로 ascending sort
# > > 215700원 납부한 고객 중에, 나이가 낮은 순서대로 정렬하기 위함
#
# - df1.sort_values(by=["col1", "col2"])
# > 선 col1 기준 sort, 후 col2 기준 sort

# %%
## 1
df1.sort_values(by="Amount_Month")
# Out:
#        Index  Member_ID Sales_Type Contract_Type Channel    Datetime  Term  \
# 35768  35770   66784964        멤버십        멤버십2유형   전문매장H  2019-02-07    36
# 43022  43024   66792946        멤버십        멤버십2유형   전문매장H  2020-06-30    36
# 49993  49995   66796388        멤버십        멤버십2유형   전문매장H  2020-03-25    36
# 33803  33805   66783630        멤버십        멤버십2유형   전문매장H  2020-07-28    36
# 45246  45248   66793779        멤버십        멤버십2유형   전문매장H  2019-07-16    36
# ...      ...        ...        ...           ...     ...         ...   ...
# 5399    5400   25742182         렌탈        프로모션계약    영업방판  2019-05-18    39
# 49896  49898   25731710         렌탈        프로모션계약    영업방판  2019-09-30    39
# 49897  49899   25731710         렌탈        프로모션계약    영업방판  2019-12-06    39
# 28147  28149   25704137         렌탈        프로모션계약    전단홍보  2019-07-25    39
# 38497  38499   25734005         렌탈        프로모션계약    영업방판  2019-06-05    39
#
# ...

# %%
## 2
df1.sort_values(by="Amount_Month", ascending=False)
# Out:
#        Index  Member_ID Sales_Type Contract_Type Channel    Datetime  Term  \
# 19773  19775   25740247         렌탈        프로모션계약    전단홍보  2019-11-14    39
# 28147  28149   25704137         렌탈        프로모션계약    전단홍보  2019-07-25    39
# 19413  19415   25710320         렌탈        프로모션계약    영업방판  2020-01-29    39
# 19412  19414   25710321         렌탈        프로모션계약    영업방판  2019-09-15    39
# 37522  37524   25733781         렌탈        프로모션계약    영업방판  2020-07-02    39
# ...      ...        ...        ...           ...     ...         ...   ...
# 45304  45306   66793756        멤버십        멤버십2유형   전문매장H  2019-10-07    36
# 50428  50430   66797402        멤버십        멤버십2유형   전문매장H  2019-12-27    36
# 45302  45304   66793342        멤버십        멤버십2유형   전문매장H  2019-04-03    36
# 41153  41155   66790864        멤버십        멤버십2유형   전문매장H  2019-02-16    36
# 39373  39375   66788207        멤버십        멤버십2유형   전문매장H  2020-05-11    36
#
# ...

# %%
## 3
df1.sort_values(by=["Amount_Month", "Age"], ascending=False)[["Amount_Month", "Age"]].head()
# Out:
#        Amount_Month   Age
# 38497        215700  58.0
# 44838        215700  51.0
# 44839        215700  51.0
# 44840        215700  51.0
# 5399         215700   NaN

# %%
## 4
df1.sort_values(by=["Amount_Month", "Overdue_count"], ascending=[False, True])[["Amount_Month", "Overdue_count"]].head()
# Out:
#        Amount_Month  Overdue_count
# 19412        215700              0
# 19413        215700              0
# 19773        215700              0
# 19774        215700              0
# 28147        215700              0

# %% [markdown]
# ### indexing & sorting

# %%
## 1 : 선 indexing, 후 sorting
df1[['Sales_Type', 'Term', 'Product_Type', 'Overdue_count']].sort_values(by="Term", ascending=False)
# Out:
#       Sales_Type  Term Product_Type  Overdue_count
# 0             렌탈    60        DES-1              0
# 31847         렌탈    60        DES-1              0
# 31849         렌탈    60        DES-1              0
# 31850         렌탈    60        DES-1              0
# 31851         렌탈    60        DES-1             11
# ...          ...   ...          ...            ...
# 21702        멤버십    12        DES-1              0
# 21703        멤버십    12        DES-1              0
# 31020        멤버십    12        DES-1              0
# 40645        멤버십    12        DES-1              0
# 35066        멤버십    12        DES-1              0
#
# [51301 rows x 4 columns]

# %%
## 2 :  col indexing -> sorting -> row indexing
df1[['Sales_Type', 'Term', 'Product_Type', 'Overdue_count']].sort_values(by="Term", ascending=False).head(50)
# Out:
#       Sales_Type  Term Product_Type  Overdue_count
# 0             렌탈    60        DES-1              0
# 31847         렌탈    60        DES-1              0
# 31849         렌탈    60        DES-1              0
# 31850         렌탈    60        DES-1              0
# 31851         렌탈    60        DES-1             11
# 31852         렌탈    60        DES-1              0
# 31853         렌탈    60        DES-2              0
# 31854         렌탈    60        DES-1              0
# 31855         렌탈    60        DES-1              0
# 31857         렌탈    60        DES-1              0
# 31858         렌탈    60        DES-2              0
# 31859         렌탈    60        DES-1              0
# 31860         렌탈    60        DES-1              0
# 31861         렌탈    60        DES-2              0
# 31862         렌탈    60        DES-1              0
# 31863         렌탈    60        DES-1              0
# 31864         렌탈    60       DES-3A              0
# ...

# %% [markdown]
# ### filtering
# 1. Contract_Type이 교체 계약인 고객 데이터만 filtering
# 2. Overdue_count가 5회 이상인 고객 데이터만 filtering
# 3.  Address1이 경기도이면서 Overdue_count가 5회 이상인  고객 데이터 filtering
# 4. Age가 30 미만이면서 Overdue_count가 5회 이상인 고객 데이터 filtering
# 5. Address1이 경기도이거나 충청도인 고객 데이터만 filtering
# 6. Sales_Type이 렌탈이고, Overdue_count가 5회 이상인 고객 데이터만 filtering 하고 Overdue_count 기준으로 descending sort했을 때 상위 10명
# 7. Sales_Type이 렌탈인 고객 들 중에서 Overdue_count 상위 10명 고객 데이터 filtering

# %%
## 1 
cond1 = (df1["Contract_Type"] == "교체계약")
df1.loc[cond1]
# Out:
#        Index  Member_ID Sales_Type Contract_Type Channel    Datetime  Term  \
# 1          2   66755948         렌탈          교체계약    영업방판  2020-02-20    60
# 29        30   66419239         렌탈          교체계약    영업방판  2019-04-08    60
# 44        45   66211709         렌탈          교체계약    영업방판  2019-12-19    60
# 45        46   66135112         렌탈          교체계약    영업방판  2019-06-20    60
# 55        56   25856039         렌탈          교체계약    영업방판  2019-05-01    60
# ...      ...        ...        ...           ...     ...         ...   ...
# 51232  51234   66231054         렌탈          교체계약    영업방판  2019-03-07    60
# 51273  51275   66814025         렌탈          교체계약   대형마트A  2019-10-23    60
# 51283  51285   66387839         렌탈          교체계약   대형마트A  2019-07-31    60
# 51287  51289   66444051         렌탈          교체계약   대형마트A  2019-09-29    60
# 51289  51291   66441028         렌탈          교체계약   대형마트A  2020-01-16    60
#
# ...

# %%
## 2
cond1 = (df1["Overdue_count"] >= 5)
df1.loc[cond1]
# Out:
#        Index  Member_ID Sales_Type Contract_Type Channel    Datetime  Term  \
# 4          5   66423204        멤버십        멤버십3유형     재계약  2019-05-10    12
# 61        62   66758851         렌탈          일반계약    영업방판  2019-01-04    60
# 95        96   25751808         렌탈        프로모션계약    영업방판  2019-01-01    60
# 341      342   66758501         렌탈        프로모션계약    영업방판  2019-01-02    39
# 347      348   66689896         렌탈        프로모션계약    영업방판  2020-07-22    60
# ...      ...        ...        ...           ...     ...         ...   ...
# 51044  51046   66796493         렌탈        프로모션계약   대형마트A  2019-02-24    60
# 51145  51147   25731398         렌탈        프로모션계약    영업방판  2019-12-19    60
# 51175  51177   66798828         렌탈        프로모션계약   전문매장H  2019-03-19    60
# 51176  51178   66787756         렌탈        프로모션계약    영업방판  2019-07-07    39
# 51291  51293   25731743         렌탈          일반계약    영업방판  2020-02-12    60
#
# ...

# %%
## 3
cond1 = (df1["Address1"] == "경기도")
cond2 = (df1["Overdue_count"] >= 5)
df1.loc[cond1 & cond2]
# Out:
#        Index  Member_ID Sales_Type Contract_Type Channel    Datetime  Term  \
# 4          5   66423204        멤버십        멤버십3유형     재계약  2019-05-10    12
# 61        62   66758851         렌탈          일반계약    영업방판  2019-01-04    60
# 95        96   25751808         렌탈        프로모션계약    영업방판  2019-01-01    60
# 633      634   66697051         렌탈        프로모션계약    영업방판  2019-01-28    60
# 900      901   66759324         렌탈         패키지계약  홈쇼핑/방송  2019-10-25    60
# ...      ...        ...        ...           ...     ...         ...   ...
# 50383  50385   66798413         렌탈        프로모션계약   대형마트A  2019-06-25    60
# 50808  50810   66218985        멤버십        멤버십3유형   대형마트A  2020-03-05    12
# 50931  50933   66798617         렌탈          일반계약    영업방판  2019-06-20    60
# 51145  51147   25731398         렌탈        프로모션계약    영업방판  2019-12-19    60
# 51291  51293   25731743         렌탈          일반계약    영업방판  2020-02-12    60
#
# ...

# %%
## 4
cond1 = (df1["Age"] < 30)
cond2 = (df1["Overdue_count"] >= 5)
df1.loc[cond1 & cond2]
# Out:
#        Index  Member_ID Sales_Type Contract_Type Channel    Datetime  Term  \
# 61        62   66758851         렌탈          일반계약    영업방판  2019-01-04    60
# 1345    1346   66758268         렌탈         패키지계약    영업방판  2019-09-17    60
# 1594    1595   66758268         렌탈          일반계약    영업방판  2020-02-12    60
# 5845    5846   66762531         렌탈         패키지계약    영업방판  2020-07-10    60
# 5846    5847   66762531         렌탈         패키지계약    영업방판  2020-07-29    60
# 6318    6319   66762154         렌탈        프로모션계약    영업방판  2019-01-12    39
# 7741    7742   66762293         렌탈         패키지계약  홈쇼핑/방송  2019-04-12    60
# 7742    7743   66762293         렌탈         패키지계약  홈쇼핑/방송  2019-04-13    60
# 7789    7790   66763046         렌탈        프로모션계약   대형마트E  2019-05-28    60
# 9638    9639   66521212         렌탈        프로모션계약    영업방판  2019-01-15    60
# 12932  12933   66140171         렌탈          교체계약    영업방판  2019-09-01    60
# ...

# %%
## 5
cond1 = (df1["Address1"] == "경기도")
cond2 = (df1["Address1"] == "충청도")
df1.loc[cond1 | cond2]
# Out:
#        Index  Member_ID Sales_Type Contract_Type Channel    Datetime  Term  \
# 0          1   66758234         렌탈          일반계약    영업방판  2019-05-06    60
# 1          2   66755948         렌탈          교체계약    영업방판  2020-02-20    60
# 2          3   66756657         렌탈          일반계약  홈쇼핑/방송  2019-02-28    60
# 3          4   66423450        멤버십        멤버십3유형     재계약  2019-05-13    12
# 4          5   66423204        멤버십        멤버십3유형     재계약  2019-05-10    12
# ...      ...        ...        ...           ...     ...         ...   ...
# 51293  51295   66799369         렌탈          일반계약   대형마트A  2020-07-10    60
# 51294  51296   66796007         렌탈        프로모션계약   대형마트A  2019-03-11    60
# 51295  51297   66792261         렌탈          일반계약  홈쇼핑/방송  2019-03-11    60
# 51296  51298   66579515         렌탈        프로모션계약   대형마트A  2019-03-01    60
# 51297  51299   66799558         렌탈          일반계약   대형마트A  2019-04-01    60
#
# ...

# %%
## 6
cond1 = (df1["Sales_Type"] == "렌탈")
cond2 = (df1["Overdue_count"] >= 5)
df1.loc[cond1 & cond2].sort_values(by="Overdue_count", ascending=False).head(10)
# Out:
#       Index  Member_ID Sales_Type Contract_Type Channel    Datetime  Term  \
# 2705   2706   66760494         렌탈         패키지계약  홈쇼핑/방송  2020-06-29    60
# 5845   5846   66762531         렌탈         패키지계약    영업방판  2020-07-10    60
# 3782   3783   66603883         렌탈          일반계약    영업방판  2019-10-28    60
# 3094   3095   66679489         렌탈        프로모션계약    영업방판  2020-06-20    60
# 3093   3094   66679489         렌탈        프로모션계약    영업방판  2020-06-20    60
# 5594   5595   66762324         렌탈        프로모션계약    영업방판  2019-06-01    39
# 95       96   25751808         렌탈        프로모션계약    영업방판  2019-01-01    60
# 5846   5847   66762531         렌탈         패키지계약    영업방판  2020-07-29    60
# 6350   6351   66763042         렌탈        프로모션계약    영업방판  2019-05-27    39
# 347     348   66689896         렌탈        프로모션계약    영업방판  2020-07-22    60
#
#      Payment_Type Product_Type  Amount_Month Customer_Type   Age Address1  \
# 2705          CMS        DES-2         81900            개인  52.0      전라도
# ...

# %%
cond1 = (df1["Sales_Type"] == "렌탈")
df1.loc[cond1].sort_values(by="Overdue_count", ascending=False).head(10)
# Out:
#       Index  Member_ID Sales_Type Contract_Type Channel    Datetime  Term  \
# 3093   3094   66679489         렌탈        프로모션계약    영업방판  2020-06-20    60
# 5846   5847   66762531         렌탈         패키지계약    영업방판  2020-07-29    60
# 2705   2706   66760494         렌탈         패키지계약  홈쇼핑/방송  2020-06-29    60
# 95       96   25751808         렌탈        프로모션계약    영업방판  2019-01-01    60
# 341     342   66758501         렌탈        프로모션계약    영업방판  2019-01-02    39
# 3782   3783   66603883         렌탈          일반계약    영업방판  2019-10-28    60
# 5594   5595   66762324         렌탈        프로모션계약    영업방판  2019-06-01    39
# 5845   5846   66762531         렌탈         패키지계약    영업방판  2020-07-10    60
# 3094   3095   66679489         렌탈        프로모션계약    영업방판  2020-06-20    60
# 347     348   66689896         렌탈        프로모션계약    영업방판  2020-07-22    60
#
#      Payment_Type Product_Type  Amount_Month Customer_Type   Age Address1  \
# 3093          CMS       DES-3A         90900            개인  58.0    서울특별시
# ...

# %% [markdown]
# ### Datetime
# - pd.to_datetime(df1["col1"], format="문자열 형식")
# - 주문일
# > - 요일별 주문량
# > - 일자별 수량합계
#
# - 배송시작일
# - 배송완료일

# %%
df1 = pd.read_csv("03_Delivery.csv", encoding="cp949")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46749 entries, 0 to 46748
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   결제수단    46749 non-null  object
#  1   배송번호    46749 non-null  object
#  2   배송시작일   46749 non-null  object
#  3   배송완료일   46749 non-null  object
#  4   상품구매금액  46749 non-null  int64
#  5   상품번호    46661 non-null  float64
#  6   수량      46749 non-null  int64
#  7   주문경로    46749 non-null  object
#  8   주문일     46749 non-null  int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 3.2+ MB

# %%
df1["주문일"]
# Out:
# 0        20181227
# 1        20181229
# 2        20181230
# 3        20181231
# 4        20181231
#            ...
# 46744    20171229
# 46745    20171229
# 46746    20171230
# 46747    20171231
# 46748    20171231
# Name: 주문일, Length: 46749, dtype: int64

# %%
df1["주문일(datetime)"] = pd.to_datetime(df1["주문일"], format="%Y%m%d")

# %%
df1
# Out:
#         결제수단                   배송번호                배송시작일               배송완료일  \
# 0      무통장입금  D-20181227-0000648-00   2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 1      무통장입금  D-20181229-0000119-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 2      무통장입금  D-20181230-0000100-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 3      무통장입금  D-20181231-0000087-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 4      무통장입금  D-20181231-0000108-00   2019-01-07 오전 8:56  2019-01-11 오전 5:32
# ...      ...                    ...                  ...                 ...
# 46744     카드  D-20171229-0000036-00   2017-12-29 오후 4:32  2018-01-02 오전 5:31
# 46745     카드  D-20171229-0000043-00   2018-01-03 오전 9:45  2018-01-07 오전 5:38
# 46746     카드  D-20171230-0000022-01   2018-01-02 오후 7:06  2018-01-11 오전 2:46
# 46747     카드  D-20171231-0000017-01   2018-01-03 오후 2:00  2018-01-06 오후 6:06
# 46748     카드  D-20171231-0000026-00  2018-01-03 오후 12:43  2018-01-07 오전 5:38
#
# ...

# %%
df1["주문연도"] = df1["주문일(datetime)"].dt.year
df1["주문월"] = df1["주문일(datetime)"].dt.month
df1["주문주차"] = df1["주문일(datetime)"].dt.isocalendar().week
df1["주문요일"] = df1["주문일(datetime)"].dt.day_name()
df1
# Out:
#         결제수단                   배송번호                배송시작일               배송완료일  \
# 0      무통장입금  D-20181227-0000648-00   2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 1      무통장입금  D-20181229-0000119-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 2      무통장입금  D-20181230-0000100-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 3      무통장입금  D-20181231-0000087-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 4      무통장입금  D-20181231-0000108-00   2019-01-07 오전 8:56  2019-01-11 오전 5:32
# ...      ...                    ...                  ...                 ...
# 46744     카드  D-20171229-0000036-00   2017-12-29 오후 4:32  2018-01-02 오전 5:31
# 46745     카드  D-20171229-0000043-00   2018-01-03 오전 9:45  2018-01-07 오전 5:38
# 46746     카드  D-20171230-0000022-01   2018-01-02 오후 7:06  2018-01-11 오전 2:46
# 46747     카드  D-20171231-0000017-01   2018-01-03 오후 2:00  2018-01-06 오후 6:06
# 46748     카드  D-20171231-0000026-00  2018-01-03 오후 12:43  2018-01-07 오전 5:38
#
# ...

# %%
# 요일별 주문량
import seaborn as sns
sns.countplot(data=df1, x="주문요일")
# Out:
# <Axes: xlabel='주문요일', ylabel='count'>
# C:\Users\USER\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\USER\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\USER\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\USER\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\USER\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
## 일자별 주문량 확인
import matplotlib as mpl
mpl.rc("font", family="Malgun Gothic")
#df1.pivot_table(index="주문일(datetime)", values="수량", aggfunc=sum).plot()
sns.lineplot(data=df1, x="주문일(datetime)", y="상품구매금액", estimator=sum)
# Out:
# <Axes: xlabel='주문일(datetime)', ylabel='상품구매금액'>

# %%
df1.pivot_table(index="주문일(datetime)", values="수량", aggfunc=sum).sort_values(by="수량", ascending=False).head(1)
# Out:
#                 수량
# 주문일(datetime)
# 2019-01-28     442

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46749 entries, 0 to 46748
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   결제수단           46749 non-null  object
#  1   배송번호           46749 non-null  object
#  2   배송시작일          46749 non-null  object
#  3   배송완료일          46749 non-null  object
#  4   상품구매금액         46749 non-null  int64
#  5   상품번호           46661 non-null  float64
#  6   수량             46749 non-null  int64
#  7   주문경로           46749 non-null  object
#  8   주문일            46749 non-null  int64
#  9   주문일(datetime)  46749 non-null  datetime64[ns]
#  10  주문연도           46749 non-null  int64
#  11  주문월            46749 non-null  int64
#  12  주문주차           46749 non-null  UInt32
#  13  주문요일           46749 non-null  object
# dtypes: UInt32(1), datetime64[ns](1), float64(1), int64(5), object(6)
# memory usage: 4.9+ MB

# %% [markdown]
# ## outliers
# - 수량: -1
# > - 제거: df2 = df1.loc[~cond1]
# > - 대체(missing value 없는 방법, 개수도 같음, -1만 1로 변환):
# >> df1["수량(clean)"] = df1["수량"]  <br>
#    cond1 = (df1["수량(clean)"] < 0)  <br>
#    df1.loc[cond1, "수량(clean)"] = 1 <br>
#
# - 상품번호: 999999
# > - NaN으로 대체 <br>
# > cond1 = (df1["상품번호"] == 999999) <br>
#   df1.loc[cond1, "상품번호"] = np.nan <br>
#   cond2 = (df1["상품번호"].isnull()) <br>
#   df1.loc[cond2]

# %%
df1 = pd.read_csv("03_Delivery.csv", encoding="cp949")

# %%
pd.options.display.float_format = "{:.2f}".format
df1.describe()
# Out:
#           상품구매금액      상품번호       수량         주문일
# count   46749.00  46661.00 46749.00    46749.00
# mean    69368.14    891.68     1.18 20184044.49
# std     66112.47  11339.53     0.68     5192.40
# min         0.00     38.00    -1.00 20170101.00
# 25%     32880.00    378.00     1.00 20180727.00
# 50%     67780.00    928.00     1.00 20181118.00
# 75%     92130.00   1209.00     1.00 20190225.00
# max   4963400.00 999999.00    50.00 20190619.00

# %%
cond1 = (df1['수량'] < 0)
df1.loc[cond1]
# Out:
#            결제수단                   배송번호                배송시작일  \
# 11        무통장입금  D-20181231-0000205-01   2019-01-03 오전 9:30
# 22        무통장입금  D-20181231-0000635-00   2019-01-03 오전 9:30
# 97           카드  D-20190102-0000193-00   2019-01-03 오전 9:28
# 334          카드  D-20190103-0000849-03   2019-01-07 오전 8:56
# 445       무통장입금  D-20190104-0000596-01   2019-01-08 오전 8:43
# 502          카드  D-20190105-0000109-00   2019-01-08 오전 8:43
# 583      적립금,카드  D-20190107-0000092-00   2019-01-08 오전 8:43
# 898   적립금,무통장입금  D-20190109-0000411-00   2019-01-10 오전 9:09
# 970       무통장입금  D-20190109-0000959-00  2019-01-11 오전 10:10
# 1240         카드  D-20190113-0000092-01   2019-01-15 오전 9:06
# 1681      무통장입금  D-20190116-0000511-00   2019-01-17 오전 9:54
# 2014      무통장입금  D-20190121-0000077-00   2019-01-22 오전 9:04
# 2212      무통장입금  D-20190122-0000426-00   2019-01-22 오후 6:18
# 2341  적립금,무통장입금  D-20190123-0000529-01   2019-01-23 오후 6:50
# 2416    실시간계좌이체  D-20190123-0001039-01   2019-01-24 오후 6:34
# ...

# %%
df2 = df1.loc[~cond1]

# %%
df2.describe().loc["min", "수량"]
# Out:
# 1.0

# %%
df1.loc[cond1, "수량"]
# Out:
# 11     -1
# 22     -1
# 97     -1
# 334    -1
# 445    -1
# 502    -1
# 583    -1
# 898    -1
# 970    -1
# 1240   -1
# 1681   -1
# 2014   -1
# 2212   -1
# 2341   -1
# 2416   -1
# 2464   -1
# Name: 수량, dtype: int64

# %%
df1.loc[cond1, "수량"] = 1
df1.describe().loc["min", "수량"]
# Out:
# 1.0

# %%
df1 = pd.read_csv("03_Delivery.csv", encoding="cp949")
df1.describe().loc["min", "수량"]
# Out:
# -1.0

# %%
df1["수량(clean)"] = df1["수량"]
cond1 = (df1["수량(clean)"] < 0)
df1.loc[cond1, "수량(clean)"] = 1
print(df1.describe().loc["min", "수량(clean)"])
print(df1.describe().loc["min", "수량"])
# Out:
# 1.0
# -1.0

# %%
import numpy as np
cond1 = (df1["상품번호"] == 999999)
df1.loc[cond1, "상품번호"] = np.nan

cond2 = (df1["상품번호"].isnull())
df1.loc[cond2]
# Out:
#             결제수단                   배송번호               배송시작일  \
# 2521          카드  D-20190124-0000418-01  2019-01-24 오후 6:34
# 2524       무통장입금  D-20190124-0000435-01  2019-01-24 오후 6:32
# 2526       무통장입금  D-20190124-0000440-00  2019-01-24 오후 6:32
# 2528       무통장입금  D-20190124-0000456-01  2019-01-24 오후 6:32
# 2529       무통장입금  D-20190124-0000456-02  2019-01-24 오후 6:32
# ...          ...                    ...                 ...
# 45416         카드  D-20170605-0000056-00  2017-06-07 오후 4:19
# 45417         카드  D-20170606-0000010-00  2017-06-07 오후 4:19
# 45418         카드  D-20170606-0000026-01  2017-06-07 오후 4:21
# 45421  적립금,무통장입금  D-20170607-0000018-00  2017-06-07 오후 4:19
# 45422      무통장입금  D-20170607-0000031-00  2017-06-07 오후 4:19
#
#                      배송완료일  상품구매금액  상품번호  수량    주문경로       주문일  수량(clean)
# 2521    2019-02-02 오전 6:30   78870   NaN   1  네이버 페이  20190124          1
# 2524    2019-01-28 오전 5:32   75240   NaN   1   PC쇼핑몰  20190124          1
# ...

# %%
import pandas as pd

# %%
df1 = pd.read_csv("03_Delivery.csv", encoding="cp949")

# %%
df1.head()
# Out:
#     결제수단                   배송번호               배송시작일               배송완료일  \
# 0  무통장입금  D-20181227-0000648-00  2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 1  무통장입금  D-20181229-0000119-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 2  무통장입금  D-20181230-0000100-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 3  무통장입금  D-20181231-0000087-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 4  무통장입금  D-20181231-0000108-00  2019-01-07 오전 8:56  2019-01-11 오전 5:32
#
#    상품구매금액    상품번호  수량   주문경로       주문일
# 0   71450  1077.0   1  PC쇼핑몰  20181227
# 1  141240    42.0   2   모바일웹  20181229
# 2   13910  1271.0   1   모바일웹  20181230
# 3   81600  1085.0   1   모바일웹  20181231
# 4   94710  1106.0   1   모바일웹  20181231

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46749 entries, 0 to 46748
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   결제수단    46749 non-null  object
#  1   배송번호    46749 non-null  object
#  2   배송시작일   46749 non-null  object
#  3   배송완료일   46749 non-null  object
#  4   상품구매금액  46749 non-null  int64
#  5   상품번호    46661 non-null  float64
#  6   수량      46749 non-null  int64
#  7   주문경로    46749 non-null  object
#  8   주문일     46749 non-null  int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 3.2+ MB

# %%
# 시간 관련 col
df1[["배송시작일", "배송완료일", "주문일"]]
# Out:
#                      배송시작일               배송완료일       주문일
# 0       2019-01-07 오전 8:56  2019-01-11 오전 5:32  20181227
# 1       2019-01-03 오전 9:30  2019-01-07 오전 5:32  20181229
# 2       2019-01-03 오전 9:30  2019-01-07 오전 5:32  20181230
# 3       2019-01-03 오전 9:30  2019-01-07 오전 5:32  20181231
# 4       2019-01-07 오전 8:56  2019-01-11 오전 5:32  20181231
# ...                    ...                 ...       ...
# 46744   2017-12-29 오후 4:32  2018-01-02 오전 5:31  20171229
# 46745   2018-01-03 오전 9:45  2018-01-07 오전 5:38  20171229
# 46746   2018-01-02 오후 7:06  2018-01-11 오전 2:46  20171230
# 46747   2018-01-03 오후 2:00  2018-01-06 오후 6:06  20171231
# 46748  2018-01-03 오후 12:43  2018-01-07 오전 5:38  20171231
#
# [46749 rows x 3 columns]

# %%
df1["주문일(datetime)"] = pd.to_datetime(df1["주문일"], format="%Y%m%d")
df1.head(1)
# Out:
#     결제수단                   배송번호               배송시작일               배송완료일  \
# 0  무통장입금  D-20181227-0000648-00  2019-01-07 오전 8:56  2019-01-11 오전 5:32
#
#    상품구매금액    상품번호  수량   주문경로       주문일 주문일(datetime)
# 0   71450  1077.0   1  PC쇼핑몰  20181227    2018-12-27

# %%
df1["주문일(datetime)"]
# Out:
# 0       2018-12-27
# 1       2018-12-29
# 2       2018-12-30
# 3       2018-12-31
# 4       2018-12-31
#            ...
# 46744   2017-12-29
# 46745   2017-12-29
# 46746   2017-12-30
# 46747   2017-12-31
# 46748   2017-12-31
# Name: 주문일(datetime), Length: 46749, dtype: datetime64[ns]

# %%
pd.options.display.float_format = "{:.2f}".format
df1["수량"].describe()
# Out:
# count   46749.00
# mean        1.18
# std         0.68
# min        -1.00
# 25%         1.00
# 50%         1.00
# 75%         1.00
# max        50.00
# Name: 수량, dtype: float64

# %%
df1.pivot_table(index="주문일(datetime)", values="수량")
# Out:
#                 수량
# 주문일(datetime)
# 2017-01-01    1.00
# 2017-01-15    1.00
# 2017-01-18    1.00
# 2017-01-23    1.00
# 2017-02-02    1.00
# ...            ...
# 2019-05-31    1.19
# 2019-06-01    1.00
# 2019-06-02    1.25
# 2019-06-04    1.00
# 2019-06-19    1.00
#
# [807 rows x 1 columns]

# %%
df1.pivot_table(index="주문일(datetime)", values="수량", aggfunc="sum")
# Out:
#                수량
# 주문일(datetime)
# 2017-01-01      1
# 2017-01-15      1
# 2017-01-18      1
# 2017-01-23      1
# 2017-02-02      1
# ...            ..
# 2019-05-31     88
# 2019-06-01      1
# 2019-06-02      5
# 2019-06-04      1
# 2019-06-19      2
#
# [807 rows x 1 columns]

# %%
# 주문일로부터 ( )만 추출해오기
df1["주문연도"] = df1["주문일(datetime)"].dt.year
df1["주문월"] = df1["주문일(datetime)"].dt.month
df1["주문주차"] = df1["주문일(datetime)"].dt.isocalendar().week
df1["주문요일"] = df1["주문일(datetime)"].dt.day_name()
df1.head(1)
# Out:
#     결제수단                   배송번호               배송시작일               배송완료일  \
# 0  무통장입금  D-20181227-0000648-00  2019-01-07 오전 8:56  2019-01-11 오전 5:32
#
#    상품구매금액    상품번호  수량   주문경로       주문일 주문일(datetime)  주문연도  주문월  주문주차  \
# 0   71450 1077.00   1  PC쇼핑몰  20181227    2018-12-27  2018   12    52
#
#        주문요일
# 0  Thursday

# %%
import matplotlib as mpl
mpl.rc("font", family="Malgun Gothic")
import seaborn as sns

# %%
# 요일별 주문량: 주중, 주말 판매 추이가 다르다.
sns.countplot(data=df1, x="주문요일")
# Out:
# <Axes: xlabel='주문요일', ylabel='count'>

# %%
# 일별 상품구매금액의 총합(매출)
sns.lineplot(data=df1, x="주문일(datetime)", y="상품구매금액", estimator="sum")
# Out:
# <Axes: xlabel='주문일(datetime)', ylabel='상품구매금액'>
